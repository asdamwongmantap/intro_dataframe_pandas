# %%
import pandas as pd
import numpy as np

# %%
data = {'nim': [2011901, 2011902,2011903], 'nama': ['Asdam', 'Amir',np.nan],'prodi':['Sistem Informasi','Sistem Informasi','Teknik Informatika']}
df = pd.DataFrame(data)

# %%
# show all data
df
# Out:
#        nim   nama               prodi
# 0  2011901  Asdam    Sistem Informasi
# 1  2011902   Amir    Sistem Informasi
# 2  2011903    NaN  Teknik Informatika

# %%
# show only top 1 data
df.head(1)
# Out:
#        nim   nama             prodi
# 0  2011901  Asdam  Sistem Informasi

# %%
df.dtypes
# Out:
# nim       int64
# nama     object
# prodi    object
# dtype: object

# %%
df.astype({'nama': 'string'}).dtypes
# Out:
# nim       int64
# nama     string
# prodi    object
# dtype: object

# %%
df_copy = df.copy()
df_copy
# Out:
#        nim   nama               prodi
# 0  2011901  Asdam    Sistem Informasi
# 1  2011902   Amir    Sistem Informasi
# 2  2011903    NaN  Teknik Informatika

# %%
df.dropna()
# Out:
#        nim   nama             prodi
# 0  2011901  Asdam  Sistem Informasi
# 1  2011902   Amir  Sistem Informasi

# %%
df.fillna('unknown',inplace=True)
df
# Out:
#        nim     nama               prodi
# 0  2011901    Asdam    Sistem Informasi
# 1  2011902     Amir    Sistem Informasi
# 2  2011903  unknown  Teknik Informatika

# %%
df

# %%
grp = df.groupby(['prodi'])
grp.first()
# Out:
#                         nim     nama
# prodi
# Sistem Informasi    2011901    Asdam
# Teknik Informatika  2011903  unknown

# %%
df.rename(columns={"prodi": "program_studi"})
# Out:
#        nim     nama       program_studi
# 0  2011901    Asdam    Sistem Informasi
# 1  2011902     Amir    Sistem Informasi
# 2  2011903  unknown  Teknik Informatika

# %%
df.to_excel('data_mahasiswa_pandas.xlsx')

# %%
df.to_csv('data_mahasiswa_pandas.csv')

# %%
df.to_json('data_mahasiswa_pandas.json')
